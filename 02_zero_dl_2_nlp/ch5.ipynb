# %%
import sys
sys.path.append('..')
import numpy as np
from common.time_layers import *

class SimpleRnnlm:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        rnn_Wx = (rn(D, H) / np.sqrt(D)).astype('f')
        rnn_Wh = (rn(H, H) / np.sqrt(H)).astype('f')
        rnn_b = np.zeros(H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.layers = [
            TimeEmbedding(embed_W),
            TimeRNN(rnn_Wx, rnn_Wh, rnn_b),
            TimeAffine(affine_W, affine_b)
        ]

        self.loss_layer = TimeSoftmaxWithLoss()
        self.rnn_layer = self.layers[1]

        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, xs, ts):
        for layer in self.layers:
            xs = layer.forward(xs)

        loss = self.loss_layer.forward(xs, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        self.rnn_layer.reset_state()

# %%
import sys
sys.path.append('..')
import matplotlib.pyplot as plt
import numpy as np
from common.optimizer import SGD
from dataset import ptb

# ハイパーパラメータの設定
batch_size = 10
wordvec_size = 100
hidden_size = 100
time_size = 5  # Truncated BPTTの展開する時間サイズ
lr = 0.1
max_epoch = 100

# 学習データの読み込み（データセットを小さくする）
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_size = 1000
corpus = corpus[:corpus_size]
vocab_size = int(max(corpus) + 1)

xs = corpus[:-1]  # 入力
ts = corpus[1:]  # 出力（教師ラベル）
data_size = len(xs)
print('corpus size: %d, vocabulary size: %d' % (corpus_size, vocab_size))

# 学習時に使用する変数
max_iters = data_size // (batch_size * time_size)
time_idx = 0
total_loss = 0
loss_count = 0
ppl_list = []

# モデルの生成
model = SimpleRnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)

# ミニバッチの各サンプルの読み込み開始位置を計算
jump = (corpus_size - 1) // batch_size
offsets = [i * jump for i in range(batch_size)]

for epoch in range(max_epoch):
    for iter in range(max_iters):
        # ミニバッチの取得
        batch_x = np.empty((batch_size, time_size), dtype='i')
        batch_t = np.empty((batch_size, time_size), dtype='i')
        for t in range(time_size):
            for i, offset in enumerate(offsets):
                batch_x[i, t] = xs[(offset + time_idx) % data_size]
                batch_t[i, t] = ts[(offset + time_idx) % data_size]
            time_idx += 1

        # 勾配を求め、パラメータを更新
        loss = model.forward(batch_x, batch_t)
        model.backward()
        optimizer.update(model.params, model.grads)
        total_loss += loss
        loss_count += 1

    # エポックごとにパープレキシティの評価
    ppl = np.exp(total_loss / loss_count)
    print('| epoch %d | perplexity %.2f'
          % (epoch+1, ppl))
    ppl_list.append(float(ppl))
    total_loss, loss_count = 0, 0

# グラフの描画
x = np.arange(len(ppl_list))
plt.plot(x, ppl_list, label='train')
plt.xlabel('epochs')
plt.ylabel('perplexity')
plt.show()
# Out:
# corpus size: 1000, vocabulary size: 418
# | epoch 1 | perplexity 408.02
# | epoch 2 | perplexity 371.62
# | epoch 3 | perplexity 304.75
# | epoch 4 | perplexity 271.66
# | epoch 5 | perplexity 246.60
# | epoch 6 | perplexity 232.91
# | epoch 7 | perplexity 222.13
# | epoch 8 | perplexity 216.71
# | epoch 9 | perplexity 207.14
# | epoch 10 | perplexity 208.36
# | epoch 11 | perplexity 203.05
# | epoch 12 | perplexity 201.18
# | epoch 13 | perplexity 199.35
# | epoch 14 | perplexity 198.29
# | epoch 15 | perplexity 195.82
# | epoch 16 | perplexity 190.44
# | epoch 17 | perplexity 187.50
# | epoch 18 | perplexity 185.50
# | epoch 19 | perplexity 184.52
# | epoch 20 | perplexity 183.97
# | epoch 21 | perplexity 182.36
# | epoch 22 | perplexity 177.34
# | epoch 23 | perplexity 175.60
# | epoch 24 | perplexity 175.03
# | epoch 25 | perplexity 170.31
# | epoch 26 | perplexity 172.75
# | epoch 27 | perplexity 168.51
# | epoch 28 | perplexity 165.29
# | epoch 29 | perplexity 163.13
# | epoch 30 | perplexity 158.42
# | epoch 31 | perplexity 159.49
# | epoch 32 | perplexity 156.68
# | epoch 33 | perplexity 155.07
# | epoch 34 | perplexity 151.11
# | epoch 35 | perplexity 151.55
# | epoch 36 | perplexity 146.25
# | epoch 37 | perplexity 144.12
# | epoch 38 | perplexity 141.28
# | epoch 39 | perplexity 135.43
# | epoch 40 | perplexity 133.78
# | epoch 41 | perplexity 136.55
# | epoch 42 | perplexity 130.68
# | epoch 43 | perplexity 124.59
# | epoch 44 | perplexity 120.40
# | epoch 45 | perplexity 121.38
# | epoch 46 | perplexity 121.37
# | epoch 47 | perplexity 115.95
# | epoch 48 | perplexity 108.07
# | epoch 49 | perplexity 107.23
# | epoch 50 | perplexity 106.10
# | epoch 51 | perplexity 104.02
# | epoch 52 | perplexity 100.00
# | epoch 53 | perplexity 95.51
# | epoch 54 | perplexity 95.99
# | epoch 55 | perplexity 93.14
# | epoch 56 | perplexity 88.99
# | epoch 57 | perplexity 86.47
# | epoch 58 | perplexity 80.99
# | epoch 59 | perplexity 79.56
# | epoch 60 | perplexity 77.90
# | epoch 61 | perplexity 77.13
# | epoch 62 | perplexity 73.04
# | epoch 63 | perplexity 67.42
# | epoch 64 | perplexity 68.16
# | epoch 65 | perplexity 67.60
# | epoch 66 | perplexity 63.17
# | epoch 67 | perplexity 61.24
# | epoch 68 | perplexity 55.64
# | epoch 69 | perplexity 56.55
# | epoch 70 | perplexity 55.09
# | epoch 71 | perplexity 51.88
# | epoch 72 | perplexity 50.46
# | epoch 73 | perplexity 48.38
# | epoch 74 | perplexity 47.87
# | epoch 75 | perplexity 47.01
# | epoch 76 | perplexity 43.69
# | epoch 77 | perplexity 41.78
# | epoch 78 | perplexity 40.37
# | epoch 79 | perplexity 39.58
# | epoch 80 | perplexity 37.28
# | epoch 81 | perplexity 36.29
# | epoch 82 | perplexity 36.07
# | epoch 83 | perplexity 33.16
# | epoch 84 | perplexity 33.83
# | epoch 85 | perplexity 31.91
# | epoch 86 | perplexity 30.77
# | epoch 87 | perplexity 29.75
# | epoch 88 | perplexity 28.45
# | epoch 89 | perplexity 27.88
# | epoch 90 | perplexity 26.41
# | epoch 91 | perplexity 26.46
# | epoch 92 | perplexity 24.78
# | epoch 93 | perplexity 24.80
# | epoch 94 | perplexity 24.03
# | epoch 95 | perplexity 23.21
# | epoch 96 | perplexity 22.63
# | epoch 97 | perplexity 21.38
# | epoch 98 | perplexity 20.55
# | epoch 99 | perplexity 20.22
# | epoch 100 | perplexity 19.74

# %%
import sys
sys.path.append('..')
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from dataset import ptb


# ハイパーパラメータの設定
batch_size = 10
wordvec_size = 100
hidden_size = 100  # RNNの隠れ状態ベクトルの要素数
time_size = 5  # RNNを展開するサイズ
lr = 0.1
max_epoch = 100

# 学習データの読み込み
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_size = 1000  # テスト用にデータセットを小さくする
corpus = corpus[:corpus_size]
vocab_size = int(max(corpus) + 1)
xs = corpus[:-1]  # 入力
ts = corpus[1:]  # 出力（教師ラベル）

# モデルの生成
model = SimpleRnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

trainer.fit(xs, ts, max_epoch, batch_size, time_size)
trainer.plot()
# Out:
# | epoch 1 |  iter 1 / 19 | time 0[s] | perplexity 418.75
# | epoch 2 |  iter 1 / 19 | time 1[s] | perplexity 398.53
# | epoch 3 |  iter 1 / 19 | time 3[s] | perplexity 346.75
# | epoch 4 |  iter 1 / 19 | time 4[s] | perplexity 285.73
# | epoch 5 |  iter 1 / 19 | time 6[s] | perplexity 261.88
# | epoch 6 |  iter 1 / 19 | time 7[s] | perplexity 243.74
# | epoch 7 |  iter 1 / 19 | time 9[s] | perplexity 222.16
# | epoch 8 |  iter 1 / 19 | time 11[s] | perplexity 220.27
# | epoch 9 |  iter 1 / 19 | time 12[s] | perplexity 215.55
# | epoch 10 |  iter 1 / 19 | time 13[s] | perplexity 204.51
# | epoch 11 |  iter 1 / 19 | time 15[s] | perplexity 208.94
# | epoch 12 |  iter 1 / 19 | time 17[s] | perplexity 198.16
# | epoch 13 |  iter 1 / 19 | time 18[s] | perplexity 202.44
# | epoch 14 |  iter 1 / 19 | time 19[s] | perplexity 197.12
# | epoch 15 |  iter 1 / 19 | time 20[s] | perplexity 195.19
# | epoch 16 |  iter 1 / 19 | time 21[s] | perplexity 195.51
# | epoch 17 |  iter 1 / 19 | time 23[s] | perplexity 191.63
# | epoch 18 |  iter 1 / 19 | time 24[s] | perplexity 188.09
# | epoch 19 |  iter 1 / 19 | time 26[s] | perplexity 183.44
# | epoch 20 |  iter 1 / 19 | time 27[s] | perplexity 184.31
# | epoch 21 |  iter 1 / 19 | time 29[s] | perplexity 178.80
# | epoch 22 |  iter 1 / 19 | time 31[s] | perplexity 177.22
# | epoch 23 |  iter 1 / 19 | time 33[s] | perplexity 179.43
# | epoch 24 |  iter 1 / 19 | time 34[s] | perplexity 176.89
# | epoch 25 |  iter 1 / 19 | time 35[s] | perplexity 169.59
# | epoch 26 |  iter 1 / 19 | time 36[s] | perplexity 168.79
# | epoch 27 |  iter 1 / 19 | time 38[s] | perplexity 170.47
# | epoch 28 |  iter 1 / 19 | time 39[s] | perplexity 169.92
# | epoch 29 |  iter 1 / 19 | time 41[s] | perplexity 162.76
# | epoch 30 |  iter 1 / 19 | time 42[s] | perplexity 160.13
# | epoch 31 |  iter 1 / 19 | time 44[s] | perplexity 158.77
# | epoch 32 |  iter 1 / 19 | time 45[s] | perplexity 154.82
# | epoch 33 |  iter 1 / 19 | time 47[s] | perplexity 154.45
# | epoch 34 |  iter 1 / 19 | time 49[s] | perplexity 152.60
# | epoch 35 |  iter 1 / 19 | time 50[s] | perplexity 148.38
# | epoch 36 |  iter 1 / 19 | time 51[s] | perplexity 145.92
# | epoch 37 |  iter 1 / 19 | time 53[s] | perplexity 148.94
# | epoch 38 |  iter 1 / 19 | time 54[s] | perplexity 140.89
# | epoch 39 |  iter 1 / 19 | time 54[s] | perplexity 139.05
# | epoch 40 |  iter 1 / 19 | time 55[s] | perplexity 132.65
# | epoch 41 |  iter 1 / 19 | time 56[s] | perplexity 128.78
# | epoch 42 |  iter 1 / 19 | time 57[s] | perplexity 132.81
# | epoch 43 |  iter 1 / 19 | time 59[s] | perplexity 125.82
# | epoch 44 |  iter 1 / 19 | time 60[s] | perplexity 123.97
# | epoch 45 |  iter 1 / 19 | time 62[s] | perplexity 115.47
# | epoch 46 |  iter 1 / 19 | time 64[s] | perplexity 116.87
# | epoch 47 |  iter 1 / 19 | time 65[s] | perplexity 116.74
# | epoch 48 |  iter 1 / 19 | time 66[s] | perplexity 111.94
# | epoch 49 |  iter 1 / 19 | time 68[s] | perplexity 109.51
# | epoch 50 |  iter 1 / 19 | time 69[s] | perplexity 101.63
# | epoch 51 |  iter 1 / 19 | time 71[s] | perplexity 102.22
# | epoch 52 |  iter 1 / 19 | time 72[s] | perplexity 97.21
# | epoch 53 |  iter 1 / 19 | time 74[s] | perplexity 95.40
# | epoch 54 |  iter 1 / 19 | time 75[s] | perplexity 92.51
# | epoch 55 |  iter 1 / 19 | time 77[s] | perplexity 90.13
# | epoch 56 |  iter 1 / 19 | time 80[s] | perplexity 86.27
# | epoch 57 |  iter 1 / 19 | time 82[s] | perplexity 88.41
# | epoch 58 |  iter 1 / 19 | time 83[s] | perplexity 82.03
# | epoch 59 |  iter 1 / 19 | time 84[s] | perplexity 78.58
# | epoch 60 |  iter 1 / 19 | time 85[s] | perplexity 75.32
# | epoch 61 |  iter 1 / 19 | time 87[s] | perplexity 72.76
# | epoch 62 |  iter 1 / 19 | time 89[s] | perplexity 71.36
# | epoch 63 |  iter 1 / 19 | time 90[s] | perplexity 70.22
# | epoch 64 |  iter 1 / 19 | time 92[s] | perplexity 67.38
# | epoch 65 |  iter 1 / 19 | time 93[s] | perplexity 62.33
# | epoch 66 |  iter 1 / 19 | time 95[s] | perplexity 62.48
# | epoch 67 |  iter 1 / 19 | time 96[s] | perplexity 60.67
# | epoch 68 |  iter 1 / 19 | time 97[s] | perplexity 57.77
# | epoch 69 |  iter 1 / 19 | time 98[s] | perplexity 55.90
# | epoch 70 |  iter 1 / 19 | time 99[s] | perplexity 53.31
# | epoch 71 |  iter 1 / 19 | time 101[s] | perplexity 51.71
# | epoch 72 |  iter 1 / 19 | time 102[s] | perplexity 49.28
# | epoch 73 |  iter 1 / 19 | time 104[s] | perplexity 48.16
# | epoch 74 |  iter 1 / 19 | time 106[s] | perplexity 45.99
# | epoch 75 |  iter 1 / 19 | time 107[s] | perplexity 45.01
# | epoch 76 |  iter 1 / 19 | time 109[s] | perplexity 44.33
# | epoch 77 |  iter 1 / 19 | time 110[s] | perplexity 42.92
# | epoch 78 |  iter 1 / 19 | time 111[s] | perplexity 40.62
# | epoch 79 |  iter 1 / 19 | time 112[s] | perplexity 39.20
# | epoch 80 |  iter 1 / 19 | time 112[s] | perplexity 37.42
# | epoch 81 |  iter 1 / 19 | time 114[s] | perplexity 36.79
# | epoch 82 |  iter 1 / 19 | time 115[s] | perplexity 35.65
# | epoch 83 |  iter 1 / 19 | time 116[s] | perplexity 34.52
# | epoch 84 |  iter 1 / 19 | time 117[s] | perplexity 32.85
# | epoch 85 |  iter 1 / 19 | time 119[s] | perplexity 31.83
# | epoch 86 |  iter 1 / 19 | time 120[s] | perplexity 31.15
# | epoch 87 |  iter 1 / 19 | time 121[s] | perplexity 30.51
# | epoch 88 |  iter 1 / 19 | time 122[s] | perplexity 28.21
# | epoch 89 |  iter 1 / 19 | time 123[s] | perplexity 28.18
# | epoch 90 |  iter 1 / 19 | time 125[s] | perplexity 27.32
# | epoch 91 |  iter 1 / 19 | time 127[s] | perplexity 26.56
# | epoch 92 |  iter 1 / 19 | time 128[s] | perplexity 25.80
# | epoch 93 |  iter 1 / 19 | time 130[s] | perplexity 24.07
# | epoch 94 |  iter 1 / 19 | time 131[s] | perplexity 23.80
# | epoch 95 |  iter 1 / 19 | time 132[s] | perplexity 23.27
# | epoch 96 |  iter 1 / 19 | time 134[s] | perplexity 22.96
# | epoch 97 |  iter 1 / 19 | time 135[s] | perplexity 21.98
# | epoch 98 |  iter 1 / 19 | time 136[s] | perplexity 21.16
# | epoch 99 |  iter 1 / 19 | time 137[s] | perplexity 20.73
# | epoch 100 |  iter 1 / 19 | time 138[s] | perplexity 20.12
