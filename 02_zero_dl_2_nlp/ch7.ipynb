# %%
import sys
sys.path.append('..')
import numpy as np
from common.functions import softmax
from rnnlm import Rnnlm
from better_rnnlm import BetterRnnlm

class RnnlmGen(Rnnlm):
    def generate(self, start_id, skip_ids=None, sample_size=100):
        word_ids = [start_id]

        x = start_id
        while len(word_ids) < sample_size:
            x = np.array(x).reshape(1, 1)
            score = self.predict(x)
            p = softmax(score.flatten())

            sampled = np.random.choice(len(p), size=1, p=p)
            if (skip_ids is None) or (sampled not in skip_ids):
                x = sampled
                word_ids.append(int(x))

        return word_ids

    def get_state(self):
        return self.lstm_layer.h, self.lstm_layer.c

    def set_state(self, state):
        self.lstm_layer.set_state(*state)

class BetterRnnlmGen(BetterRnnlm):
    def generate(self, start_id, skip_ids=None, sample_size=100):
        word_ids = [start_id]

        x = start_id
        while len(word_ids) < sample_size:
            x = np.array(x).reshape(1, 1)
            score = self.predict(x).flatten()
            p = softmax(score).flatten()

            sampled = np.random.choice(len(p), size=1, p=p)
            if (skip_ids is None) or (sampled not in skip_ids):
                x = sampled
                word_ids.append(int(x))

        return word_ids

    def get_state(self):
        states = []
        for layer in self.lstm_layers:
            states.append((layer.h, layer.c))
        return states

    def set_state(self, states):
        for layer, state in zip(self.lstm_layers, states):
            layer.set_state(*state)

# %%
import sys
sys.path.append('..')

from dataset import ptb 

corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)
corpus_size = len(corpus)

model = RnnlmGen()
model.load_params('./Rnnlm.pkl')

# start文字とskip文字の設定
start_word = 'you'
start_id = word_to_id[start_word]
skip_words = ['N', '<unk>', '$']
skip_ids = [word_to_id[w] for w in skip_words]
# 文章生成
word_ids = model.generate(start_id, skip_ids)
txt = ' '.join([id_to_word[i] for i in word_ids])
txt = txt.replace(' <eos>', '.\n')
print(txt)
# Out:
# you closed compared with all legitimate chains in europe.
#  index industries fell at higher prices making up a wave of slowing in growth markets in midland unisys europe 's hanson cells because they lost or eight off west germany among the consensus particularly higher.
#  british petroleum co..
#  in a secondary market analysts said in august river d. ariz. was named an baltimore consulting computer officer at salomon sponsored the economist but said his credibility might appear to have begun only to invest but most costs greatly only committed to a buyer position of departments and beautiful qintex

# %%
corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)
corpus_size = len(corpus)


model = BetterRnnlmGen()
model.load_params('./BetterRnnlm.pkl')

# start文字とskip文字の設定
start_word = 'you'
start_id = word_to_id[start_word]
skip_words = ['N', '<unk>', '$']
skip_ids = [word_to_id[w] for w in skip_words]
# 文章生成
word_ids = model.generate(start_id, skip_ids)
txt = ' '.join([id_to_word[i] for i in word_ids])
txt = txt.replace(' <eos>', '.\n')

print(txt)


model.reset_state()

start_words = 'the meaning of life is'
start_ids = [word_to_id[w] for w in start_words.split(' ')]

for x in start_ids[:-1]:
    x = np.array(x).reshape(1, 1)
    model.predict(x)

word_ids = model.generate(start_ids[-1], skip_ids)
word_ids = start_ids[:-1] + word_ids
txt = ' '.join([id_to_word[i] for i in word_ids])
txt = txt.replace(' <eos>', '.\n')
print('-' * 50)
print(txt)
# Out:
# you did n't worry about completing new plans.
#  but the organization defined in the heart of a battle of performances against its terrible viability and bush knows how much mexico miss kevin cabrera had a workout with residents of the ec committee.
#  mr. dinkins 's former mayor ally nancy giuliani said his secret city is an important frenzy to adding all the quality of his property in concentrated allies.
#  look for accepting the withdrawal of his own american home containing develop differences their youth as in the cuban television industry had just only any more an explanation
# --------------------------------------------------
# the meaning of life is what they learn about further political barriers.
#  account could be used to finance the liability of local natural gas and is earmarked in an effort to focus into the creativity of the university contractor.
#  the guild responded to the discussions ordinarily with two federal death programs in canadian forms.
#  many of officials urging us to this more fairly cut for instance.
#  but we did n't have it going to get a mistake to worry n't these days and to all it.
#  it 's just how in fact to us belong to many questions mr.

# %%
# coding: utf-8
import sys
sys.path.append('..')
from dataset import sequence


(x_train, t_train), (x_test, t_test) = \
    sequence.load_data('addition.txt', seed=1984)
char_to_id, id_to_char = sequence.get_vocab()

print(x_train.shape, t_train.shape)
print(x_test.shape, t_test.shape)
# (45000, 7) (45000, 5)
# (5000, 7) (5000, 5)

print(x_train[0])
print(t_train[0])
# [ 3  0  2  0  0 11  5]
# [ 6  0 11  7  5]

print(''.join([id_to_char[c] for c in x_train[0]]))
print(''.join([id_to_char[c] for c in t_train[0]]))
# 71+118
# _189
# Out:
# (45000, 7) (45000, 5)
# (5000, 7) (5000, 5)
# [ 3  0  2  0  0 11  5]
# [ 6  0 11  7  5]
# 71+118
# _189

# %%
# %%writefile ch7_encoder.py
import sys
sys.path.append('..')
from common.time_layers import *
from common.base_model import BaseModel

class Encoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4*H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful = False)

        self.params = self.embed.params + self.lstm.params
        self.grads = self.embed.grads + self.lstm.grads
        self.hs = None

    def forward(self, xs):
        xs = self.embed.forward(xs)
        hs = self.lstm.forward(xs)
        self.hs = hs 
        return hs[:, -1, :]

    def backward(self, dh):
        dhs = np.zeros_like(self.hs)
        dhs[:, -1, :] = dh 

        dout = self.lstm.backward(dhs)
        dout = self.embed.backward(dout)

        return dout

# %%
# %%writefile ch7_decoder.py
import sys
sys.path.append('..')
from common.time_layers import *
from common.base_model import BaseModel

class Decoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4*H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful = True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []

        for layer in (self.embed, self.lstm, self.affine):
            self.params += layer.params
            self.grads += layer.grads

    def forward(self, xs, h):
        self.lstm.set_state(h)

        out = self.embed.forward(xs)
        out = self.lstm.forward(out)
        score = self.affine.forward(out)
        return score

    def backward(self, dscore):
        dout = self.affine.backward(dscore)
        dout = self.lstm.backward(dout)
        dout = self.embed.backward(dout)
        dh = self.lstm.dh
        return dh

    def generate(self, h, start_id, sample_size):
        sampled = []
        sample_id = start_id
        self.lstm.set_state(h)

        for _ in range(sample_size):
            x = np.array(sample_id).reshape((1, 1))
            out = self.embed.forward(x)
            out = self.lstm.forward(out)
            score = self.affine.forward(out)

            sample_id = np.argmax(score.flatten())
            sampled.append(int(sample_id))

        return sampled

# %%
# %%writefile ch7_seq2seq.py
import sys
sys.path.append('..')
from common.time_layers import *
from common.base_model import BaseModel 
class Seq2seq(BaseModel):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = Encoder(V, D, H)
        self.decoder = Decoder(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

    def forward(self, xs, ts):
        decoder_xs, decoder_ts = ts[:, :-1], ts[:, 1:]

        h = self.encoder.forward(xs)
        score = self.decoder.forward(decoder_xs, h)
        loss = self.softmax.forward(score, decoder_ts)
        return loss

    def backward(self, dout=1):
        dout = self.softmax.backward(dout)
        dh = self.decoder.backward(dout)
        dout = self.encoder.backward(dh)
        return dout

    def generate(self, xs, start_id, sample_size):
        h = self.encoder.forward(xs)
        sampled = self.decoder.generate(h, start_id, sample_size)
        return sampled

# %%
import sys, os
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq

# データセットの読み込み
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

# ハイパーパラメータの設定
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

model = Seq2seq(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1,
                batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct,
                                    id_to_char, verbose)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('val acc %.3f%%' % (acc * 100))

# グラフの描画
x = np.arange(len(acc_list))
plt.plot(x, acc_list, marker='o')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.ylim(0, 1.0)
plt.show()
# Out:
# | epoch 1 |  iter 1 / 351 | time 1[s] | loss 2.56
# | epoch 1 |  iter 21 / 351 | time 53[s] | loss 2.53
# | epoch 1 |  iter 41 / 351 | time 103[s] | loss 2.17
# | epoch 1 |  iter 61 / 351 | time 152[s] | loss 1.96
# | epoch 1 |  iter 81 / 351 | time 204[s] | loss 1.92
# | epoch 1 |  iter 101 / 351 | time 255[s] | loss 1.87
# | epoch 1 |  iter 121 / 351 | time 307[s] | loss 1.85
# | epoch 1 |  iter 141 / 351 | time 356[s] | loss 1.83
# | epoch 1 |  iter 161 / 351 | time 406[s] | loss 1.79
# | epoch 1 |  iter 181 / 351 | time 452[s] | loss 1.77
# | epoch 1 |  iter 201 / 351 | time 502[s] | loss 1.77
# | epoch 1 |  iter 221 / 351 | time 549[s] | loss 1.76
# | epoch 1 |  iter 241 / 351 | time 590[s] | loss 1.76
# | epoch 1 |  iter 261 / 351 | time 608[s] | loss 1.76
# | epoch 1 |  iter 281 / 351 | time 620[s] | loss 1.75
# | epoch 1 |  iter 301 / 351 | time 642[s] | loss 1.74
# | epoch 1 |  iter 321 / 351 | time 678[s] | loss 1.75
# | epoch 1 |  iter 341 / 351 | time 710[s] | loss 1.74
# Q 77+85
# T 162
# ☒ 100
# ---
# Q 975+164
# T 1139
# ☒ 1000
# ---
# Q 582+84
# T 666
# ☒ 1000
# ---
# Q 8+155
# T 163
# ☒ 100
# ---
# Q 367+55
# T 422
# ☒ 1000
# ---
# Q 600+257
# T 857
# ☒ 1000
# ---
# Q 761+292
# T 1053
# ☒ 1000
# ---
# Q 830+597
# T 1427
# ☒ 1000
# ---
# Q 26+838
# T 864
# ☒ 1000
# ---
# Q 143+93
# T 236
# ☒ 100
# ---
# val acc 0.180%
# | epoch 2 |  iter 1 / 351 | time 1[s] | loss 1.74
# | epoch 2 |  iter 21 / 351 | time 41[s] | loss 1.73
# | epoch 2 |  iter 41 / 351 | time 77[s] | loss 1.74
# | epoch 2 |  iter 61 / 351 | time 125[s] | loss 1.74
# | epoch 2 |  iter 81 / 351 | time 158[s] | loss 1.73
# | epoch 2 |  iter 101 / 351 | time 199[s] | loss 1.73
# | epoch 2 |  iter 121 / 351 | time 239[s] | loss 1.72
# | epoch 2 |  iter 141 / 351 | time 280[s] | loss 1.71
# | epoch 2 |  iter 161 / 351 | time 315[s] | loss 1.71
# | epoch 2 |  iter 181 / 351 | time 356[s] | loss 1.71
# | epoch 2 |  iter 201 / 351 | time 397[s] | loss 1.70
# | epoch 2 |  iter 221 / 351 | time 442[s] | loss 1.71
# | epoch 2 |  iter 241 / 351 | time 496[s] | loss 1.70
# | epoch 2 |  iter 261 / 351 | time 538[s] | loss 1.69
# | epoch 2 |  iter 281 / 351 | time 563[s] | loss 1.69
# | epoch 2 |  iter 301 / 351 | time 592[s] | loss 1.69
# | epoch 2 |  iter 321 / 351 | time 609[s] | loss 1.68
# | epoch 2 |  iter 341 / 351 | time 627[s] | loss 1.67
# Q 77+85
# T 162
# ☒ 994
# ---
# Q 975+164
# T 1139
# ☒ 1000
# ---
# Q 582+84
# T 666
# ☒ 700
# ---
# Q 8+155
# T 163
# ☒ 100
# ---
# Q 367+55
# T 422
# ☒ 400
# ---
# Q 600+257
# T 857
# ☒ 1000
# ---
# Q 761+292
# T 1053
# ☒ 1000
# ---
# Q 830+597
# T 1427
# ☒ 1544
# ---
# Q 26+838
# T 864
# ☒ 400
# ---
# Q 143+93
# T 236
# ☒ 400
# ---
# val acc 0.220%
# | epoch 3 |  iter 1 / 351 | time 0[s] | loss 1.66
# | epoch 3 |  iter 21 / 351 | time 12[s] | loss 1.66
# | epoch 3 |  iter 41 / 351 | time 23[s] | loss 1.65
# | epoch 3 |  iter 61 / 351 | time 34[s] | loss 1.63
# | epoch 3 |  iter 81 / 351 | time 46[s] | loss 1.62
# | epoch 3 |  iter 101 / 351 | time 57[s] | loss 1.62
# | epoch 3 |  iter 121 / 351 | time 70[s] | loss 1.60
# | epoch 3 |  iter 141 / 351 | time 82[s] | loss 1.59
# | epoch 3 |  iter 161 / 351 | time 94[s] | loss 1.57
# | epoch 3 |  iter 181 / 351 | time 106[s] | loss 1.57
# | epoch 3 |  iter 201 / 351 | time 117[s] | loss 1.56
# | epoch 3 |  iter 221 / 351 | time 131[s] | loss 1.54
# | epoch 3 |  iter 241 / 351 | time 142[s] | loss 1.52
# | epoch 3 |  iter 261 / 351 | time 152[s] | loss 1.52
# | epoch 3 |  iter 281 / 351 | time 164[s] | loss 1.52
# | epoch 3 |  iter 301 / 351 | time 174[s] | loss 1.50
# | epoch 3 |  iter 321 / 351 | time 184[s] | loss 1.49
# | epoch 3 |  iter 341 / 351 | time 195[s] | loss 1.48
# Q 77+85
# T 162
# ☒ 108
# ---
# Q 975+164
# T 1139
# ☒ 1001
# ---
# Q 582+84
# T 666
# ☒ 648
# ---
# Q 8+155
# T 163
# ☒ 138
# ---
# Q 367+55
# T 422
# ☒ 448
# ---
# Q 600+257
# T 857
# ☒ 848
# ---
# Q 761+292
# T 1053
# ☒ 1011
# ---
# Q 830+597
# T 1427
# ☒ 1373
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 348
# ---
# val acc 0.560%
# | epoch 4 |  iter 1 / 351 | time 0[s] | loss 1.47
# | epoch 4 |  iter 21 / 351 | time 1[s] | loss 1.46
# | epoch 4 |  iter 41 / 351 | time 3[s] | loss 1.44
# | epoch 4 |  iter 61 / 351 | time 5[s] | loss 1.43
# | epoch 4 |  iter 81 / 351 | time 7[s] | loss 1.42
# | epoch 4 |  iter 101 / 351 | time 9[s] | loss 1.41
# | epoch 4 |  iter 121 / 351 | time 11[s] | loss 1.40
# | epoch 4 |  iter 141 / 351 | time 12[s] | loss 1.40
# | epoch 4 |  iter 161 / 351 | time 14[s] | loss 1.38
# | epoch 4 |  iter 181 / 351 | time 16[s] | loss 1.38
# | epoch 4 |  iter 201 / 351 | time 17[s] | loss 1.37
# | epoch 4 |  iter 221 / 351 | time 19[s] | loss 1.35
# | epoch 4 |  iter 241 / 351 | time 21[s] | loss 1.33
# | epoch 4 |  iter 261 / 351 | time 22[s] | loss 1.33
# | epoch 4 |  iter 281 / 351 | time 24[s] | loss 1.33
# | epoch 4 |  iter 301 / 351 | time 26[s] | loss 1.32
# | epoch 4 |  iter 321 / 351 | time 27[s] | loss 1.31
# | epoch 4 |  iter 341 / 351 | time 29[s] | loss 1.30
# Q 77+85
# T 162
# ☒ 146
# ---
# Q 975+164
# T 1139
# ☒ 1189
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 432
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☒ 1002
# ---
# Q 830+597
# T 1427
# ☒ 1406
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☒ 202
# ---
# val acc 1.060%
# | epoch 5 |  iter 1 / 351 | time 0[s] | loss 1.28
# | epoch 5 |  iter 21 / 351 | time 1[s] | loss 1.29
# | epoch 5 |  iter 41 / 351 | time 3[s] | loss 1.28
# | epoch 5 |  iter 61 / 351 | time 5[s] | loss 1.27
# | epoch 5 |  iter 81 / 351 | time 6[s] | loss 1.27
# | epoch 5 |  iter 101 / 351 | time 7[s] | loss 1.26
# | epoch 5 |  iter 121 / 351 | time 9[s] | loss 1.26
# | epoch 5 |  iter 141 / 351 | time 10[s] | loss 1.27
# | epoch 5 |  iter 161 / 351 | time 12[s] | loss 1.26
# | epoch 5 |  iter 181 / 351 | time 13[s] | loss 1.25
# | epoch 5 |  iter 201 / 351 | time 15[s] | loss 1.23
# | epoch 5 |  iter 221 / 351 | time 16[s] | loss 1.22
# | epoch 5 |  iter 241 / 351 | time 18[s] | loss 1.21
# | epoch 5 |  iter 261 / 351 | time 19[s] | loss 1.21
# | epoch 5 |  iter 281 / 351 | time 21[s] | loss 1.21
# | epoch 5 |  iter 301 / 351 | time 22[s] | loss 1.20
# | epoch 5 |  iter 321 / 351 | time 24[s] | loss 1.19
# | epoch 5 |  iter 341 / 351 | time 26[s] | loss 1.18
# Q 77+85
# T 162
# ☒ 145
# ---
# Q 975+164
# T 1139
# ☒ 1168
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 192
# ---
# Q 367+55
# T 422
# ☒ 431
# ---
# Q 600+257
# T 857
# ☒ 895
# ---
# Q 761+292
# T 1053
# ☒ 1015
# ---
# Q 830+597
# T 1427
# ☒ 1493
# ---
# Q 26+838
# T 864
# ☒ 891
# ---
# Q 143+93
# T 236
# ☒ 221
# ---
# val acc 2.260%
# | epoch 6 |  iter 1 / 351 | time 0[s] | loss 1.17
# | epoch 6 |  iter 21 / 351 | time 1[s] | loss 1.17
# | epoch 6 |  iter 41 / 351 | time 3[s] | loss 1.18
# | epoch 6 |  iter 61 / 351 | time 5[s] | loss 1.17
# | epoch 6 |  iter 81 / 351 | time 6[s] | loss 1.16
# | epoch 6 |  iter 101 / 351 | time 7[s] | loss 1.16
# | epoch 6 |  iter 121 / 351 | time 9[s] | loss 1.16
# | epoch 6 |  iter 141 / 351 | time 10[s] | loss 1.14
# | epoch 6 |  iter 161 / 351 | time 12[s] | loss 1.14
# | epoch 6 |  iter 181 / 351 | time 13[s] | loss 1.13
# | epoch 6 |  iter 201 / 351 | time 15[s] | loss 1.15
# | epoch 6 |  iter 221 / 351 | time 16[s] | loss 1.14
# | epoch 6 |  iter 241 / 351 | time 18[s] | loss 1.13
# | epoch 6 |  iter 261 / 351 | time 20[s] | loss 1.11
# | epoch 6 |  iter 281 / 351 | time 21[s] | loss 1.16
# | epoch 6 |  iter 301 / 351 | time 23[s] | loss 1.13
# | epoch 6 |  iter 321 / 351 | time 24[s] | loss 1.10
# | epoch 6 |  iter 341 / 351 | time 26[s] | loss 1.10
# Q 77+85
# T 162
# ☒ 166
# ---
# Q 975+164
# T 1139
# ☒ 1191
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 199
# ---
# Q 367+55
# T 422
# ☒ 440
# ---
# Q 600+257
# T 857
# ☒ 870
# ---
# Q 761+292
# T 1053
# ☒ 1011
# ---
# Q 830+597
# T 1427
# ☒ 1410
# ---
# Q 26+838
# T 864
# ☒ 856
# ---
# Q 143+93
# T 236
# ☒ 270
# ---
# val acc 2.800%
# | epoch 7 |  iter 1 / 351 | time 0[s] | loss 1.12
# | epoch 7 |  iter 21 / 351 | time 2[s] | loss 1.11
# | epoch 7 |  iter 41 / 351 | time 3[s] | loss 1.09
# | epoch 7 |  iter 61 / 351 | time 5[s] | loss 1.10
# | epoch 7 |  iter 81 / 351 | time 7[s] | loss 1.09
# | epoch 7 |  iter 101 / 351 | time 9[s] | loss 1.09
# | epoch 7 |  iter 121 / 351 | time 11[s] | loss 1.09
# | epoch 7 |  iter 141 / 351 | time 13[s] | loss 1.07
# | epoch 7 |  iter 161 / 351 | time 14[s] | loss 1.08
# | epoch 7 |  iter 181 / 351 | time 16[s] | loss 1.07
# | epoch 7 |  iter 201 / 351 | time 17[s] | loss 1.07
# | epoch 7 |  iter 221 / 351 | time 19[s] | loss 1.06
# | epoch 7 |  iter 241 / 351 | time 20[s] | loss 1.06
# | epoch 7 |  iter 261 / 351 | time 22[s] | loss 1.08
# | epoch 7 |  iter 281 / 351 | time 23[s] | loss 1.07
# | epoch 7 |  iter 301 / 351 | time 25[s] | loss 1.06
# | epoch 7 |  iter 321 / 351 | time 26[s] | loss 1.05
# | epoch 7 |  iter 341 / 351 | time 28[s] | loss 1.04
# Q 77+85
# T 162
# ☒ 166
# ---
# Q 975+164
# T 1139
# ☒ 1166
# ---
# Q 582+84
# T 666
# ☒ 668
# ---
# Q 8+155
# T 163
# ☒ 161
# ---
# Q 367+55
# T 422
# ☒ 418
# ---
# Q 600+257
# T 857
# ☒ 892
# ---
# Q 761+292
# T 1053
# ☒ 1058
# ---
# Q 830+597
# T 1427
# ☒ 1444
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 228
# ---
# val acc 3.500%
# | epoch 8 |  iter 1 / 351 | time 0[s] | loss 1.06
# | epoch 8 |  iter 21 / 351 | time 18[s] | loss 1.05
# | epoch 8 |  iter 41 / 351 | time 38[s] | loss 1.05
# | epoch 8 |  iter 61 / 351 | time 60[s] | loss 1.04
# | epoch 8 |  iter 81 / 351 | time 86[s] | loss 1.03
# | epoch 8 |  iter 101 / 351 | time 113[s] | loss 1.05
# | epoch 8 |  iter 121 / 351 | time 142[s] | loss 1.04
# | epoch 8 |  iter 141 / 351 | time 162[s] | loss 1.04
# | epoch 8 |  iter 161 / 351 | time 183[s] | loss 1.03
# | epoch 8 |  iter 181 / 351 | time 213[s] | loss 1.02
# | epoch 8 |  iter 201 / 351 | time 240[s] | loss 1.03
# | epoch 8 |  iter 221 / 351 | time 264[s] | loss 1.01
# | epoch 8 |  iter 241 / 351 | time 289[s] | loss 1.01
# | epoch 8 |  iter 261 / 351 | time 313[s] | loss 1.01
# | epoch 8 |  iter 281 / 351 | time 342[s] | loss 1.02
# | epoch 8 |  iter 301 / 351 | time 368[s] | loss 1.01
# | epoch 8 |  iter 321 / 351 | time 394[s] | loss 1.01
# | epoch 8 |  iter 341 / 351 | time 408[s] | loss 1.00
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1160
# ---
# Q 582+84
# T 666
# ☒ 658
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 431
# ---
# Q 600+257
# T 857
# ☒ 853
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1449
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# val acc 5.200%
# | epoch 9 |  iter 1 / 351 | time 1[s] | loss 1.00
# | epoch 9 |  iter 21 / 351 | time 12[s] | loss 1.03
# | epoch 9 |  iter 41 / 351 | time 27[s] | loss 1.01
# | epoch 9 |  iter 61 / 351 | time 48[s] | loss 0.99
# | epoch 9 |  iter 81 / 351 | time 69[s] | loss 1.00
# | epoch 9 |  iter 101 / 351 | time 93[s] | loss 0.99
# | epoch 9 |  iter 121 / 351 | time 115[s] | loss 1.03
# | epoch 9 |  iter 141 / 351 | time 153[s] | loss 1.04
# | epoch 9 |  iter 161 / 351 | time 180[s] | loss 1.01
# | epoch 9 |  iter 181 / 351 | time 204[s] | loss 0.97
# | epoch 9 |  iter 201 / 351 | time 230[s] | loss 0.98
# | epoch 9 |  iter 221 / 351 | time 255[s] | loss 0.98
# | epoch 9 |  iter 241 / 351 | time 281[s] | loss 1.00
# | epoch 9 |  iter 261 / 351 | time 306[s] | loss 0.99
# | epoch 9 |  iter 281 / 351 | time 335[s] | loss 0.98
# | epoch 9 |  iter 301 / 351 | time 364[s] | loss 0.98
# | epoch 9 |  iter 321 / 351 | time 391[s] | loss 0.99
# | epoch 9 |  iter 341 / 351 | time 416[s] | loss 0.97
# Q 77+85
# T 162
# ☒ 167
# ---
# Q 975+164
# T 1139
# ☒ 1128
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 158
# ---
# Q 367+55
# T 422
# ☒ 418
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1425
# ---
# Q 26+838
# T 864
# ☒ 857
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# val acc 5.100%
# | epoch 10 |  iter 1 / 351 | time 1[s] | loss 0.95
# | epoch 10 |  iter 21 / 351 | time 19[s] | loss 0.97
# | epoch 10 |  iter 41 / 351 | time 36[s] | loss 0.96
# | epoch 10 |  iter 61 / 351 | time 56[s] | loss 0.98
# | epoch 10 |  iter 81 / 351 | time 75[s] | loss 0.96
# | epoch 10 |  iter 101 / 351 | time 96[s] | loss 0.98
# | epoch 10 |  iter 121 / 351 | time 113[s] | loss 0.97
# | epoch 10 |  iter 141 / 351 | time 132[s] | loss 0.97
# | epoch 10 |  iter 161 / 351 | time 150[s] | loss 0.96
# | epoch 10 |  iter 181 / 351 | time 169[s] | loss 0.96
# | epoch 10 |  iter 201 / 351 | time 193[s] | loss 0.97
# | epoch 10 |  iter 221 / 351 | time 215[s] | loss 0.95
# | epoch 10 |  iter 241 / 351 | time 236[s] | loss 0.98
# | epoch 10 |  iter 261 / 351 | time 258[s] | loss 0.97
# | epoch 10 |  iter 281 / 351 | time 279[s] | loss 0.96
# | epoch 10 |  iter 301 / 351 | time 303[s] | loss 0.96
# | epoch 10 |  iter 321 / 351 | time 324[s] | loss 0.96
# | epoch 10 |  iter 341 / 351 | time 348[s] | loss 0.94
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1166
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 173
# ---
# Q 367+55
# T 422
# ☒ 430
# ---
# Q 600+257
# T 857
# ☒ 890
# ---
# Q 761+292
# T 1053
# ☒ 1075
# ---
# Q 830+597
# T 1427
# ☒ 1460
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 247
# ---
# val acc 3.980%
# | epoch 11 |  iter 1 / 351 | time 0[s] | loss 1.01
# | epoch 11 |  iter 21 / 351 | time 16[s] | loss 0.98
# | epoch 11 |  iter 41 / 351 | time 32[s] | loss 0.96
# | epoch 11 |  iter 61 / 351 | time 48[s] | loss 0.94
# | epoch 11 |  iter 81 / 351 | time 67[s] | loss 0.98
# | epoch 11 |  iter 101 / 351 | time 90[s] | loss 0.98
# | epoch 11 |  iter 121 / 351 | time 113[s] | loss 0.95
# | epoch 11 |  iter 141 / 351 | time 138[s] | loss 0.93
# | epoch 11 |  iter 161 / 351 | time 174[s] | loss 0.94
# | epoch 11 |  iter 181 / 351 | time 206[s] | loss 0.94
# | epoch 11 |  iter 201 / 351 | time 234[s] | loss 0.94
# | epoch 11 |  iter 221 / 351 | time 262[s] | loss 0.93
# | epoch 11 |  iter 241 / 351 | time 287[s] | loss 1.00
# | epoch 11 |  iter 261 / 351 | time 318[s] | loss 0.94
# | epoch 11 |  iter 281 / 351 | time 350[s] | loss 0.93
# | epoch 11 |  iter 301 / 351 | time 385[s] | loss 0.93
# | epoch 11 |  iter 321 / 351 | time 422[s] | loss 0.93
# | epoch 11 |  iter 341 / 351 | time 463[s] | loss 0.93
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1161
# ---
# Q 582+84
# T 666
# ☒ 668
# ---
# Q 8+155
# T 163
# ☒ 172
# ---
# Q 367+55
# T 422
# ☒ 421
# ---
# Q 600+257
# T 857
# ☒ 848
# ---
# Q 761+292
# T 1053
# ☒ 1073
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# val acc 5.520%
# | epoch 12 |  iter 1 / 351 | time 1[s] | loss 0.93
# | epoch 12 |  iter 21 / 351 | time 39[s] | loss 0.97
# | epoch 12 |  iter 41 / 351 | time 79[s] | loss 0.92
# | epoch 12 |  iter 61 / 351 | time 110[s] | loss 0.91
# | epoch 12 |  iter 81 / 351 | time 144[s] | loss 0.91
# | epoch 12 |  iter 101 / 351 | time 167[s] | loss 0.96
# | epoch 12 |  iter 121 / 351 | time 186[s] | loss 0.93
# | epoch 12 |  iter 141 / 351 | time 210[s] | loss 0.91
# | epoch 12 |  iter 161 / 351 | time 230[s] | loss 0.92
# | epoch 12 |  iter 181 / 351 | time 254[s] | loss 0.92
# | epoch 12 |  iter 201 / 351 | time 278[s] | loss 0.95
# | epoch 12 |  iter 221 / 351 | time 301[s] | loss 0.94
# | epoch 12 |  iter 241 / 351 | time 322[s] | loss 0.94
# | epoch 12 |  iter 261 / 351 | time 352[s] | loss 0.90
# | epoch 12 |  iter 281 / 351 | time 370[s] | loss 0.95
# | epoch 12 |  iter 301 / 351 | time 393[s] | loss 0.91
# | epoch 12 |  iter 321 / 351 | time 417[s] | loss 0.90
# | epoch 12 |  iter 341 / 351 | time 436[s] | loss 0.91
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☑ 1139
# ---
# Q 582+84
# T 666
# ☒ 681
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 861
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# val acc 5.860%
# | epoch 13 |  iter 1 / 351 | time 1[s] | loss 0.90
# | epoch 13 |  iter 21 / 351 | time 24[s] | loss 0.90
# | epoch 13 |  iter 41 / 351 | time 46[s] | loss 0.91
# | epoch 13 |  iter 61 / 351 | time 77[s] | loss 0.90
# | epoch 13 |  iter 81 / 351 | time 105[s] | loss 0.92
# | epoch 13 |  iter 101 / 351 | time 127[s] | loss 0.93
# | epoch 13 |  iter 121 / 351 | time 144[s] | loss 0.90
# | epoch 13 |  iter 141 / 351 | time 160[s] | loss 0.90
# | epoch 13 |  iter 161 / 351 | time 180[s] | loss 0.89
# | epoch 13 |  iter 181 / 351 | time 199[s] | loss 0.95
# | epoch 13 |  iter 201 / 351 | time 220[s] | loss 0.92
# | epoch 13 |  iter 221 / 351 | time 240[s] | loss 0.93
# | epoch 13 |  iter 241 / 351 | time 261[s] | loss 0.92
# | epoch 13 |  iter 261 / 351 | time 283[s] | loss 0.92
# | epoch 13 |  iter 281 / 351 | time 304[s] | loss 0.92
# | epoch 13 |  iter 301 / 351 | time 329[s] | loss 0.88
# | epoch 13 |  iter 321 / 351 | time 350[s] | loss 0.89
# | epoch 13 |  iter 341 / 351 | time 372[s] | loss 0.90
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1121
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 859
# ---
# Q 143+93
# T 236
# ☒ 242
# ---
# val acc 8.520%
# | epoch 14 |  iter 1 / 351 | time 1[s] | loss 0.90
# | epoch 14 |  iter 21 / 351 | time 22[s] | loss 0.89
# | epoch 14 |  iter 41 / 351 | time 43[s] | loss 0.88
# | epoch 14 |  iter 61 / 351 | time 61[s] | loss 0.90
# | epoch 14 |  iter 81 / 351 | time 78[s] | loss 0.91
# | epoch 14 |  iter 101 / 351 | time 95[s] | loss 0.91
# | epoch 14 |  iter 121 / 351 | time 112[s] | loss 0.90
# | epoch 14 |  iter 141 / 351 | time 131[s] | loss 0.88
# | epoch 14 |  iter 161 / 351 | time 151[s] | loss 0.87
# | epoch 14 |  iter 181 / 351 | time 178[s] | loss 0.88
# | epoch 14 |  iter 201 / 351 | time 200[s] | loss 0.89
# | epoch 14 |  iter 221 / 351 | time 226[s] | loss 0.92
# | epoch 14 |  iter 241 / 351 | time 258[s] | loss 0.92
# | epoch 14 |  iter 261 / 351 | time 292[s] | loss 0.91
# | epoch 14 |  iter 281 / 351 | time 328[s] | loss 0.90
# | epoch 14 |  iter 301 / 351 | time 361[s] | loss 0.90
# | epoch 14 |  iter 321 / 351 | time 394[s] | loss 0.90
# | epoch 14 |  iter 341 / 351 | time 428[s] | loss 0.88
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1128
# ---
# Q 582+84
# T 666
# ☒ 658
# ---
# Q 8+155
# T 163
# ☒ 171
# ---
# Q 367+55
# T 422
# ☒ 411
# ---
# Q 600+257
# T 857
# ☒ 855
# ---
# Q 761+292
# T 1053
# ☒ 1070
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 859
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# val acc 6.920%
# | epoch 15 |  iter 1 / 351 | time 1[s] | loss 0.84
# | epoch 15 |  iter 21 / 351 | time 14[s] | loss 0.87
# | epoch 15 |  iter 41 / 351 | time 16[s] | loss 0.87
# | epoch 15 |  iter 61 / 351 | time 18[s] | loss 0.87
# | epoch 15 |  iter 81 / 351 | time 20[s] | loss 0.87
# | epoch 15 |  iter 101 / 351 | time 22[s] | loss 0.87
# | epoch 15 |  iter 121 / 351 | time 23[s] | loss 0.87
# | epoch 15 |  iter 141 / 351 | time 25[s] | loss 0.87
# | epoch 15 |  iter 161 / 351 | time 27[s] | loss 0.88
# | epoch 15 |  iter 181 / 351 | time 28[s] | loss 0.87
# | epoch 15 |  iter 201 / 351 | time 31[s] | loss 0.92
# | epoch 15 |  iter 221 / 351 | time 33[s] | loss 0.95
# | epoch 15 |  iter 241 / 351 | time 34[s] | loss 0.89
# | epoch 15 |  iter 261 / 351 | time 36[s] | loss 0.88
# | epoch 15 |  iter 281 / 351 | time 38[s] | loss 0.91
# | epoch 15 |  iter 301 / 351 | time 39[s] | loss 0.92
# | epoch 15 |  iter 321 / 351 | time 41[s] | loss 0.90
# | epoch 15 |  iter 341 / 351 | time 43[s] | loss 0.89
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1162
# ---
# Q 582+84
# T 666
# ☒ 676
# ---
# Q 8+155
# T 163
# ☒ 168
# ---
# Q 367+55
# T 422
# ☒ 428
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☒ 1063
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# val acc 3.820%
# | epoch 16 |  iter 1 / 351 | time 0[s] | loss 0.90
# | epoch 16 |  iter 21 / 351 | time 1[s] | loss 0.89
# | epoch 16 |  iter 41 / 351 | time 3[s] | loss 0.89
# | epoch 16 |  iter 61 / 351 | time 5[s] | loss 0.88
# | epoch 16 |  iter 81 / 351 | time 6[s] | loss 0.86
# | epoch 16 |  iter 101 / 351 | time 7[s] | loss 0.87
# | epoch 16 |  iter 121 / 351 | time 9[s] | loss 0.87
# | epoch 16 |  iter 141 / 351 | time 11[s] | loss 0.86
# | epoch 16 |  iter 161 / 351 | time 12[s] | loss 0.92
# | epoch 16 |  iter 181 / 351 | time 14[s] | loss 0.90
# | epoch 16 |  iter 201 / 351 | time 15[s] | loss 0.90
# | epoch 16 |  iter 221 / 351 | time 16[s] | loss 0.87
# | epoch 16 |  iter 241 / 351 | time 18[s] | loss 0.86
# | epoch 16 |  iter 261 / 351 | time 19[s] | loss 0.88
# | epoch 16 |  iter 281 / 351 | time 21[s] | loss 0.88
# | epoch 16 |  iter 301 / 351 | time 23[s] | loss 0.88
# | epoch 16 |  iter 321 / 351 | time 24[s] | loss 0.88
# | epoch 16 |  iter 341 / 351 | time 27[s] | loss 0.87
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1127
# ---
# Q 582+84
# T 666
# ☒ 662
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 849
# ---
# Q 761+292
# T 1053
# ☒ 1072
# ---
# Q 830+597
# T 1427
# ☒ 1414
# ---
# Q 26+838
# T 864
# ☒ 852
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# val acc 6.640%
# | epoch 17 |  iter 1 / 351 | time 0[s] | loss 0.86
# | epoch 17 |  iter 21 / 351 | time 1[s] | loss 0.87
# | epoch 17 |  iter 41 / 351 | time 3[s] | loss 0.88
# | epoch 17 |  iter 61 / 351 | time 5[s] | loss 0.87
# | epoch 17 |  iter 81 / 351 | time 6[s] | loss 0.90
# | epoch 17 |  iter 101 / 351 | time 8[s] | loss 0.86
# | epoch 17 |  iter 121 / 351 | time 10[s] | loss 0.87
# | epoch 17 |  iter 141 / 351 | time 12[s] | loss 0.87
# | epoch 17 |  iter 161 / 351 | time 13[s] | loss 0.86
# | epoch 17 |  iter 181 / 351 | time 15[s] | loss 0.87
# | epoch 17 |  iter 201 / 351 | time 16[s] | loss 0.87
# | epoch 17 |  iter 221 / 351 | time 18[s] | loss 0.86
# | epoch 17 |  iter 241 / 351 | time 20[s] | loss 0.87
# | epoch 17 |  iter 261 / 351 | time 21[s] | loss 0.86
# | epoch 17 |  iter 281 / 351 | time 23[s] | loss 0.87
# | epoch 17 |  iter 301 / 351 | time 24[s] | loss 0.87
# | epoch 17 |  iter 321 / 351 | time 26[s] | loss 0.85
# | epoch 17 |  iter 341 / 351 | time 27[s] | loss 0.84
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1127
# ---
# Q 582+84
# T 666
# ☒ 658
# ---
# Q 8+155
# T 163
# ☒ 158
# ---
# Q 367+55
# T 422
# ☒ 417
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1055
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# val acc 9.060%
# | epoch 18 |  iter 1 / 351 | time 0[s] | loss 0.83
# | epoch 18 |  iter 21 / 351 | time 1[s] | loss 0.83
# | epoch 18 |  iter 41 / 351 | time 3[s] | loss 0.84
# | epoch 18 |  iter 61 / 351 | time 4[s] | loss 0.85
# | epoch 18 |  iter 81 / 351 | time 6[s] | loss 0.86
# | epoch 18 |  iter 101 / 351 | time 8[s] | loss 0.83
# | epoch 18 |  iter 121 / 351 | time 10[s] | loss 0.85
# | epoch 18 |  iter 141 / 351 | time 11[s] | loss 0.84
# | epoch 18 |  iter 161 / 351 | time 13[s] | loss 0.85
# | epoch 18 |  iter 181 / 351 | time 14[s] | loss 0.82
# | epoch 18 |  iter 201 / 351 | time 16[s] | loss 0.84
# | epoch 18 |  iter 221 / 351 | time 38[s] | loss 0.85
# | epoch 18 |  iter 241 / 351 | time 68[s] | loss 0.86
# | epoch 18 |  iter 261 / 351 | time 91[s] | loss 0.84
# | epoch 18 |  iter 281 / 351 | time 126[s] | loss 0.82
# | epoch 18 |  iter 301 / 351 | time 159[s] | loss 0.86
# | epoch 18 |  iter 321 / 351 | time 185[s] | loss 0.85
# | epoch 18 |  iter 341 / 351 | time 216[s] | loss 0.85
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1131
# ---
# Q 582+84
# T 666
# ☒ 659
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 849
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1414
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# val acc 10.260%
# | epoch 19 |  iter 1 / 351 | time 2[s] | loss 0.81
# | epoch 19 |  iter 21 / 351 | time 41[s] | loss 0.82
# | epoch 19 |  iter 41 / 351 | time 79[s] | loss 0.83
# | epoch 19 |  iter 61 / 351 | time 120[s] | loss 0.86
# | epoch 19 |  iter 81 / 351 | time 158[s] | loss 0.86
# | epoch 19 |  iter 101 / 351 | time 197[s] | loss 0.83
# | epoch 19 |  iter 121 / 351 | time 237[s] | loss 0.83
# | epoch 19 |  iter 141 / 351 | time 283[s] | loss 0.84
# | epoch 19 |  iter 161 / 351 | time 321[s] | loss 0.83
# | epoch 19 |  iter 181 / 351 | time 357[s] | loss 0.82
# | epoch 19 |  iter 201 / 351 | time 397[s] | loss 0.83
# | epoch 19 |  iter 221 / 351 | time 427[s] | loss 0.82
# | epoch 19 |  iter 241 / 351 | time 457[s] | loss 0.82
# | epoch 19 |  iter 261 / 351 | time 488[s] | loss 0.83
# | epoch 19 |  iter 281 / 351 | time 519[s] | loss 0.82
# | epoch 19 |  iter 301 / 351 | time 550[s] | loss 0.87
# | epoch 19 |  iter 321 / 351 | time 576[s] | loss 0.81
# | epoch 19 |  iter 341 / 351 | time 603[s] | loss 0.83
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1160
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 171
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☑ 857
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# val acc 8.400%
# | epoch 20 |  iter 1 / 351 | time 1[s] | loss 0.81
# | epoch 20 |  iter 21 / 351 | time 31[s] | loss 0.84
# | epoch 20 |  iter 41 / 351 | time 55[s] | loss 0.81
# | epoch 20 |  iter 61 / 351 | time 85[s] | loss 0.86
# | epoch 20 |  iter 81 / 351 | time 114[s] | loss 0.85
# | epoch 20 |  iter 101 / 351 | time 144[s] | loss 0.84
# | epoch 20 |  iter 121 / 351 | time 180[s] | loss 0.83
# | epoch 20 |  iter 141 / 351 | time 212[s] | loss 0.84
# | epoch 20 |  iter 161 / 351 | time 248[s] | loss 0.84
# | epoch 20 |  iter 181 / 351 | time 279[s] | loss 0.88
# | epoch 20 |  iter 201 / 351 | time 316[s] | loss 0.81
# | epoch 20 |  iter 221 / 351 | time 320[s] | loss 0.80
# | epoch 20 |  iter 241 / 351 | time 323[s] | loss 0.80
# | epoch 20 |  iter 261 / 351 | time 325[s] | loss 0.82
# | epoch 20 |  iter 281 / 351 | time 327[s] | loss 0.80
# | epoch 20 |  iter 301 / 351 | time 329[s] | loss 0.81
# | epoch 20 |  iter 321 / 351 | time 331[s] | loss 0.83
# | epoch 20 |  iter 341 / 351 | time 333[s] | loss 0.81
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1137
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 862
# ---
# Q 761+292
# T 1053
# ☒ 1059
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 872
# ---
# Q 143+93
# T 236
# ☒ 242
# ---
# val acc 7.600%
# | epoch 21 |  iter 1 / 351 | time 0[s] | loss 0.83
# | epoch 21 |  iter 21 / 351 | time 1[s] | loss 0.84
# | epoch 21 |  iter 41 / 351 | time 3[s] | loss 0.79
# | epoch 21 |  iter 61 / 351 | time 5[s] | loss 0.82
# | epoch 21 |  iter 81 / 351 | time 6[s] | loss 0.85
# | epoch 21 |  iter 101 / 351 | time 8[s] | loss 0.83
# | epoch 21 |  iter 121 / 351 | time 10[s] | loss 0.84
# | epoch 21 |  iter 141 / 351 | time 11[s] | loss 0.83
# | epoch 21 |  iter 161 / 351 | time 13[s] | loss 0.82
# | epoch 21 |  iter 181 / 351 | time 15[s] | loss 0.82
# | epoch 21 |  iter 201 / 351 | time 16[s] | loss 0.82
# | epoch 21 |  iter 221 / 351 | time 17[s] | loss 0.82
# | epoch 21 |  iter 241 / 351 | time 19[s] | loss 0.82
# | epoch 21 |  iter 261 / 351 | time 21[s] | loss 0.80
# | epoch 21 |  iter 281 / 351 | time 22[s] | loss 0.79
# | epoch 21 |  iter 301 / 351 | time 24[s] | loss 0.80
# | epoch 21 |  iter 321 / 351 | time 26[s] | loss 0.83
# | epoch 21 |  iter 341 / 351 | time 28[s] | loss 0.81
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1137
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1059
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 870
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# val acc 6.860%
# | epoch 22 |  iter 1 / 351 | time 0[s] | loss 0.83
# | epoch 22 |  iter 21 / 351 | time 2[s] | loss 0.78
# | epoch 22 |  iter 41 / 351 | time 3[s] | loss 0.79
# | epoch 22 |  iter 61 / 351 | time 5[s] | loss 0.80
# | epoch 22 |  iter 81 / 351 | time 6[s] | loss 0.80
# | epoch 22 |  iter 101 / 351 | time 8[s] | loss 0.78
# | epoch 22 |  iter 121 / 351 | time 10[s] | loss 0.80
# | epoch 22 |  iter 141 / 351 | time 11[s] | loss 0.84
# | epoch 22 |  iter 161 / 351 | time 13[s] | loss 0.82
# | epoch 22 |  iter 181 / 351 | time 14[s] | loss 0.81
# | epoch 22 |  iter 201 / 351 | time 16[s] | loss 0.79
# | epoch 22 |  iter 221 / 351 | time 18[s] | loss 0.82
# | epoch 22 |  iter 241 / 351 | time 19[s] | loss 0.83
# | epoch 22 |  iter 261 / 351 | time 21[s] | loss 0.80
# | epoch 22 |  iter 281 / 351 | time 23[s] | loss 0.81
# | epoch 22 |  iter 301 / 351 | time 24[s] | loss 0.81
# | epoch 22 |  iter 321 / 351 | time 26[s] | loss 0.80
# | epoch 22 |  iter 341 / 351 | time 27[s] | loss 0.78
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1120
# ---
# Q 582+84
# T 666
# ☒ 670
# ---
# Q 8+155
# T 163
# ☒ 167
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☑ 1053
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 242
# ---
# val acc 7.600%
# | epoch 23 |  iter 1 / 351 | time 0[s] | loss 0.80
# | epoch 23 |  iter 21 / 351 | time 1[s] | loss 0.82
# | epoch 23 |  iter 41 / 351 | time 3[s] | loss 0.80
# | epoch 23 |  iter 61 / 351 | time 5[s] | loss 0.80
# | epoch 23 |  iter 81 / 351 | time 6[s] | loss 0.80
# | epoch 23 |  iter 101 / 351 | time 8[s] | loss 0.80
# | epoch 23 |  iter 121 / 351 | time 10[s] | loss 0.79
# | epoch 23 |  iter 141 / 351 | time 11[s] | loss 0.77
# | epoch 23 |  iter 161 / 351 | time 13[s] | loss 0.79
# | epoch 23 |  iter 181 / 351 | time 14[s] | loss 0.84
# | epoch 23 |  iter 201 / 351 | time 16[s] | loss 0.77
# | epoch 23 |  iter 221 / 351 | time 17[s] | loss 0.78
# | epoch 23 |  iter 241 / 351 | time 19[s] | loss 0.82
# | epoch 23 |  iter 261 / 351 | time 21[s] | loss 0.82
# | epoch 23 |  iter 281 / 351 | time 23[s] | loss 0.82
# | epoch 23 |  iter 301 / 351 | time 24[s] | loss 0.78
# | epoch 23 |  iter 321 / 351 | time 26[s] | loss 0.79
# | epoch 23 |  iter 341 / 351 | time 28[s] | loss 0.81
# Q 77+85
# T 162
# ☒ 159
# ---
# Q 975+164
# T 1139
# ☒ 1107
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 415
# ---
# Q 600+257
# T 857
# ☒ 850
# ---
# Q 761+292
# T 1053
# ☒ 1038
# ---
# Q 830+597
# T 1427
# ☒ 1390
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# val acc 6.760%
# | epoch 24 |  iter 1 / 351 | time 0[s] | loss 0.83
# | epoch 24 |  iter 21 / 351 | time 2[s] | loss 0.81
# | epoch 24 |  iter 41 / 351 | time 3[s] | loss 0.83
# | epoch 24 |  iter 61 / 351 | time 5[s] | loss 0.80
# | epoch 24 |  iter 81 / 351 | time 6[s] | loss 0.80
# | epoch 24 |  iter 101 / 351 | time 8[s] | loss 0.77
# | epoch 24 |  iter 121 / 351 | time 10[s] | loss 0.78
# | epoch 24 |  iter 141 / 351 | time 11[s] | loss 0.78
# | epoch 24 |  iter 161 / 351 | time 13[s] | loss 0.78
# | epoch 24 |  iter 181 / 351 | time 15[s] | loss 0.80
# | epoch 24 |  iter 201 / 351 | time 16[s] | loss 0.82
# | epoch 24 |  iter 221 / 351 | time 18[s] | loss 0.78
# | epoch 24 |  iter 241 / 351 | time 19[s] | loss 0.78
# | epoch 24 |  iter 261 / 351 | time 21[s] | loss 0.79
# | epoch 24 |  iter 281 / 351 | time 22[s] | loss 0.78
# | epoch 24 |  iter 301 / 351 | time 24[s] | loss 0.82
# | epoch 24 |  iter 321 / 351 | time 25[s] | loss 0.78
# | epoch 24 |  iter 341 / 351 | time 27[s] | loss 0.78
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1141
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 415
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 235
# ---
# val acc 8.620%
# | epoch 25 |  iter 1 / 351 | time 0[s] | loss 0.76
# | epoch 25 |  iter 21 / 351 | time 1[s] | loss 0.77
# | epoch 25 |  iter 41 / 351 | time 3[s] | loss 0.76
# | epoch 25 |  iter 61 / 351 | time 5[s] | loss 0.75
# | epoch 25 |  iter 81 / 351 | time 7[s] | loss 0.75
# | epoch 25 |  iter 101 / 351 | time 8[s] | loss 0.82
# | epoch 25 |  iter 121 / 351 | time 9[s] | loss 0.75
# | epoch 25 |  iter 141 / 351 | time 11[s] | loss 0.76
# | epoch 25 |  iter 161 / 351 | time 12[s] | loss 0.75
# | epoch 25 |  iter 181 / 351 | time 14[s] | loss 0.76
# | epoch 25 |  iter 201 / 351 | time 16[s] | loss 0.82
# | epoch 25 |  iter 221 / 351 | time 17[s] | loss 0.79
# | epoch 25 |  iter 241 / 351 | time 19[s] | loss 0.79
# | epoch 25 |  iter 261 / 351 | time 21[s] | loss 0.78
# | epoch 25 |  iter 281 / 351 | time 22[s] | loss 0.78
# | epoch 25 |  iter 301 / 351 | time 24[s] | loss 0.79
# | epoch 25 |  iter 321 / 351 | time 25[s] | loss 0.78
# | epoch 25 |  iter 341 / 351 | time 27[s] | loss 0.79
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☒ 671
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 426
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 246
# ---
# val acc 8.360%

# %%
import sys, os
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq

# データセットの読み込み
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
x_train, x_test = x_train[:,::-1], x_test[:,::-1]
char_to_id, id_to_char = sequence.get_vocab()

# ハイパーパラメータの設定
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 5
max_grad = 5.0

model = Seq2seq(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1,
                batch_size=batch_size, max_grad=max_grad, eval_interval=100)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct,
                                    id_to_char, verbose)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('val acc %.3f%%' % (acc * 100))

# グラフの描画
x = np.arange(len(acc_list))
plt.plot(x, acc_list, marker='o')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.ylim(0, 1.0)
plt.show()
# Out:
# | epoch 1 |  iter 1 / 351 | time 0[s] | loss 2.56
# | epoch 1 |  iter 101 / 351 | time 35[s] | loss 2.09
# | epoch 1 |  iter 201 / 351 | time 191[s] | loss 1.81
# | epoch 1 |  iter 301 / 351 | time 284[s] | loss 1.75
# Q   58+77
# T 162
# ☒ 100
# ---
# Q 461+579
# T 1139
# ☒ 1000
# ---
# Q  48+285
# T 666
# ☒ 1001
# ---
# Q   551+8
# T 163
# ☒ 100
# ---
# Q  55+763
# T 422
# ☒ 1001
# ---
# Q 752+006
# T 857
# ☒ 1000
# ---
# Q 292+167
# T 1053
# ☒ 1000
# ---
# Q 795+038
# T 1427
# ☒ 1000
# ---
# Q  838+62
# T 864
# ☒ 1001
# ---
# Q  39+341
# T 236
# ☒ 703
# ---
# val acc 0.120%
# | epoch 2 |  iter 1 / 351 | time 0[s] | loss 1.73
# | epoch 2 |  iter 101 / 351 | time 38[s] | loss 1.71
# | epoch 2 |  iter 201 / 351 | time 74[s] | loss 1.67
# | epoch 2 |  iter 301 / 351 | time 146[s] | loss 1.62
# Q   58+77
# T 162
# ☒ 100
# ---
# Q 461+579
# T 1139
# ☒ 1000
# ---
# Q  48+285
# T 666
# ☒ 690
# ---
# Q   551+8
# T 163
# ☒ 1000
# ---
# Q  55+763
# T 422
# ☒ 470
# ---
# Q 752+006
# T 857
# ☒ 700
# ---
# Q 292+167
# T 1053
# ☒ 1000
# ---
# Q 795+038
# T 1427
# ☒ 1444
# ---
# Q  838+62
# T 864
# ☒ 700
# ---
# Q  39+341
# T 236
# ☒ 370
# ---
# val acc 0.400%
# | epoch 3 |  iter 1 / 351 | time 0[s] | loss 1.52
# | epoch 3 |  iter 101 / 351 | time 8[s] | loss 1.49
# | epoch 3 |  iter 201 / 351 | time 20[s] | loss 1.40
# | epoch 3 |  iter 301 / 351 | time 28[s] | loss 1.32
# Q   58+77
# T 162
# ☒ 158
# ---
# Q 461+579
# T 1139
# ☒ 1148
# ---
# Q  48+285
# T 666
# ☒ 662
# ---
# Q   551+8
# T 163
# ☒ 162
# ---
# Q  55+763
# T 422
# ☒ 382
# ---
# Q 752+006
# T 857
# ☒ 818
# ---
# Q 292+167
# T 1053
# ☒ 1008
# ---
# Q 795+038
# T 1427
# ☒ 1434
# ---
# Q  838+62
# T 864
# ☒ 838
# ---
# Q  39+341
# T 236
# ☒ 202
# ---
# val acc 1.940%
# | epoch 4 |  iter 1 / 351 | time 0[s] | loss 1.26
# | epoch 4 |  iter 101 / 351 | time 14[s] | loss 1.22
# | epoch 4 |  iter 201 / 351 | time 30[s] | loss 1.15
# | epoch 4 |  iter 301 / 351 | time 40[s] | loss 1.08
# Q   58+77
# T 162
# ☒ 166
# ---
# Q 461+579
# T 1139
# ☒ 1196
# ---
# Q  48+285
# T 666
# ☒ 668
# ---
# Q   551+8
# T 163
# ☒ 166
# ---
# Q  55+763
# T 422
# ☒ 419
# ---
# Q 752+006
# T 857
# ☒ 896
# ---
# Q 292+167
# T 1053
# ☒ 1010
# ---
# Q 795+038
# T 1427
# ☒ 1496
# ---
# Q  838+62
# T 864
# ☒ 868
# ---
# Q  39+341
# T 236
# ☒ 239
# ---
# val acc 5.780%
# | epoch 5 |  iter 1 / 351 | time 0[s] | loss 1.01
# | epoch 5 |  iter 101 / 351 | time 6[s] | loss 0.98
# | epoch 5 |  iter 201 / 351 | time 13[s] | loss 0.93
# | epoch 5 |  iter 301 / 351 | time 22[s] | loss 0.88
# Q   58+77
# T 162
# ☒ 161
# ---
# Q 461+579
# T 1139
# ☒ 1192
# ---
# Q  48+285
# T 666
# ☑ 666
# ---
# Q   551+8
# T 163
# ☒ 166
# ---
# Q  55+763
# T 422
# ☒ 421
# ---
# Q 752+006
# T 857
# ☒ 860
# ---
# Q 292+167
# T 1053
# ☒ 1066
# ---
# Q 795+038
# T 1427
# ☒ 1414
# ---
# Q  838+62
# T 864
# ☒ 865
# ---
# Q  39+341
# T 236
# ☒ 232
# ---
# val acc 12.460%

# %%
class PeekyDecoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(H + D, 4 * H) / np.sqrt(H + D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H + H, V) / np.sqrt(H + H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []
        for layer in (self.embed, self.lstm, self.affine):
            self.params += layer.params
            self.grads += layer.grads
        self.cache = None

    def forward(self, xs, h):
        N, T = xs.shape
        N, H = h.shape

        self.lstm.set_state(h)

        out = self.embed.forward(xs)
        hs = np.repeat(h, T, axis=0).reshape(N, T, H)
        out = np.concatenate((hs, out), axis=2)

        out = self.lstm.forward(out)
        out = np.concatenate((hs, out), axis=2)

        score = self.affine.forward(out)
        self.cache = H
        return score

    def backward(self, dscore):
        H = self.cache

        dout = self.affine.backward(dscore)
        dout, dhs0 = dout[:, :, H:], dout[:, :, :H]
        dout = self.lstm.backward(dout)
        dembed, dhs1 = dout[:, :, H:], dout[:, :, :H]
        self.embed.backward(dembed)

        dhs = dhs0 + dhs1
        dh = self.lstm.dh + np.sum(dhs, axis=1)
        return dh

    def generate(self, h, start_id, sample_size):
        sampled = []
        char_id = start_id
        self.lstm.set_state(h)

        H = h.shape[1]
        peeky_h = h.reshape(1, 1, H)
        for _ in range(sample_size):
            x = np.array([char_id]).reshape((1, 1))
            out = self.embed.forward(x)

            out = np.concatenate((peeky_h, out), axis=2)
            out = self.lstm.forward(out)
            out = np.concatenate((peeky_h, out), axis=2)
            score = self.affine.forward(out)

            char_id = np.argmax(score.flatten())
            sampled.append(char_id)

        return sampled


class PeekySeq2seq(Seq2seq):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = Encoder(V, D, H)
        self.decoder = PeekyDecoder(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

# %%
import sys, os
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq

# データセットの読み込み
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
x_train, x_test = x_train[:,::-1], x_test[:,::-1]
char_to_id, id_to_char = sequence.get_vocab()

# ハイパーパラメータの設定
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 5
max_grad = 5.0

model = PeekySeq2seq(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1,
                batch_size=batch_size, max_grad=max_grad, eval_interval=100)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct,
                                    id_to_char, verbose)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('val acc %.3f%%' % (acc * 100))

# グラフの描画
x = np.arange(len(acc_list))
plt.plot(x, acc_list, marker='o')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.ylim(0, 1.0)
plt.show()
# Out:
# | epoch 1 |  iter 1 / 351 | time 1[s] | loss 2.57
# | epoch 1 |  iter 101 / 351 | time 95[s] | loss 2.08
# | epoch 1 |  iter 201 / 351 | time 214[s] | loss 1.79
# | epoch 1 |  iter 301 / 351 | time 364[s] | loss 1.75
# Q   58+77
# T 162
# ☒ 100
# ---
# Q 461+579
# T 1139
# ☒ 1013
# ---
# Q  48+285
# T 666
# ☒ 102
# ---
# Q   551+8
# T 163
# ☒ 100
# ---
# Q  55+763
# T 422
# ☒ 1023
# ---
# Q 752+006
# T 857
# ☒ 1023
# ---
# Q 292+167
# T 1053
# ☒ 1023
# ---
# Q 795+038
# T 1427
# ☒ 1111
# ---
# Q  838+62
# T 864
# ☒ 102
# ---
# Q  39+341
# T 236
# ☒ 102
# ---
# val acc 0.280%
# | epoch 2 |  iter 1 / 351 | time 0[s] | loss 1.71
# | epoch 2 |  iter 101 / 351 | time 137[s] | loss 1.70
# | epoch 2 |  iter 201 / 351 | time 151[s] | loss 1.67
# | epoch 2 |  iter 301 / 351 | time 160[s] | loss 1.63
# Q   58+77
# T 162
# ☒ 100
# ---
# Q 461+579
# T 1139
# ☒ 1200
# ---
# Q  48+285
# T 666
# ☒ 690
# ---
# Q   551+8
# T 163
# ☒ 100
# ---
# Q  55+763
# T 422
# ☒ 690
# ---
# Q 752+006
# T 857
# ☒ 999
# ---
# Q 292+167
# T 1053
# ☒ 1029
# ---
# Q 795+038
# T 1427
# ☒ 1240
# ---
# Q  838+62
# T 864
# ☒ 792
# ---
# Q  39+341
# T 236
# ☒ 290
# ---
# val acc 0.400%
# | epoch 3 |  iter 1 / 351 | time 0[s] | loss 1.58
# | epoch 3 |  iter 101 / 351 | time 7[s] | loss 1.56
# | epoch 3 |  iter 201 / 351 | time 15[s] | loss 1.49
# | epoch 3 |  iter 301 / 351 | time 27[s] | loss 1.41
# Q   58+77
# T 162
# ☒ 154
# ---
# Q 461+579
# T 1139
# ☒ 1033
# ---
# Q  48+285
# T 666
# ☒ 644
# ---
# Q   551+8
# T 163
# ☒ 161
# ---
# Q  55+763
# T 422
# ☒ 433
# ---
# Q 752+006
# T 857
# ☒ 818
# ---
# Q 292+167
# T 1053
# ☒ 1018
# ---
# Q 795+038
# T 1427
# ☒ 1344
# ---
# Q  838+62
# T 864
# ☒ 834
# ---
# Q  39+341
# T 236
# ☒ 211
# ---
# val acc 1.600%
# | epoch 4 |  iter 1 / 351 | time 0[s] | loss 1.32
# | epoch 4 |  iter 101 / 351 | time 7[s] | loss 1.29
# | epoch 4 |  iter 201 / 351 | time 14[s] | loss 1.22
# | epoch 4 |  iter 301 / 351 | time 22[s] | loss 1.16
# Q   58+77
# T 162
# ☒ 158
# ---
# Q 461+579
# T 1139
# ☒ 1123
# ---
# Q  48+285
# T 666
# ☒ 657
# ---
# Q   551+8
# T 163
# ☒ 165
# ---
# Q  55+763
# T 422
# ☒ 423
# ---
# Q 752+006
# T 857
# ☒ 777
# ---
# Q 292+167
# T 1053
# ☒ 1023
# ---
# Q 795+038
# T 1427
# ☒ 1388
# ---
# Q  838+62
# T 864
# ☒ 887
# ---
# Q  39+341
# T 236
# ☒ 223
# ---
# val acc 5.140%
# | epoch 5 |  iter 1 / 351 | time 0[s] | loss 1.08
# | epoch 5 |  iter 101 / 351 | time 9[s] | loss 1.04
# | epoch 5 |  iter 201 / 351 | time 17[s] | loss 0.98
# | epoch 5 |  iter 301 / 351 | time 25[s] | loss 0.91
# Q   58+77
# T 162
# ☒ 160
# ---
# Q 461+579
# T 1139
# ☒ 1135
# ---
# Q  48+285
# T 666
# ☒ 668
# ---
# Q   551+8
# T 163
# ☒ 169
# ---
# Q  55+763
# T 422
# ☑ 422
# ---
# Q 752+006
# T 857
# ☒ 861
# ---
# Q 292+167
# T 1053
# ☒ 1045
# ---
# Q 795+038
# T 1427
# ☒ 1324
# ---
# Q  838+62
# T 864
# ☒ 861
# ---
# Q  39+341
# T 236
# ☒ 239
# ---
# val acc 9.380%
