# %%
import sys
sys.path.append('..')
from common.time_layers import *
from common.base_model import BaseModel


class Rnnlm(BaseModel):
    def __init__(self, vocab_size=10000, wordvec_size=100, hidden_size=100):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        # 重みの初期化
        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')

        # レイヤの生成
        self.layers = [
            TimeEmbedding(embed_W),
            TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True),
            TimeAffine(affine_W, affine_b)
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layer = self.layers[1]

        # すべての重みと勾配をリストにまとめる
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs):
        for layer in self.layers:
            xs = layer.forward(xs)
        return xs

    def forward(self, xs, ts):
        score = self.predict(xs)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        self.lstm_layer.reset_state()

# %%
import sys
sys.path.append('..')
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb

# ハイパーパラメータの設定
batch_size = 20
wordvec_size = 100
hidden_size = 100  # RNNの隠れ状態ベクトルの要素数
time_size = 35  # RNNを展開するサイズ
lr = 20.0
max_epoch = 4
max_grad = 0.25

# 学習データの読み込み
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# モデルの生成
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

# 勾配クリッピングを適用して学習
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad,
            eval_interval=100)
trainer.plot(ylim=(0, 500))

# テストデータで評価
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('test perplexity: ', ppl_test)

# パラメータの保存
model.save_params()
# Out:
# | epoch 1 |  iter 1 / 1327 | time 5[s] | perplexity 9999.26
# | epoch 1 |  iter 101 / 1327 | time 456[s] | perplexity 1172.84
# | epoch 1 |  iter 201 / 1327 | time 970[s] | perplexity 577.17
# | epoch 1 |  iter 301 / 1327 | time 1447[s] | perplexity 446.94
# | epoch 1 |  iter 401 / 1327 | time 1895[s] | perplexity 368.51
# | epoch 1 |  iter 501 / 1327 | time 2195[s] | perplexity 323.50
# | epoch 1 |  iter 601 / 1327 | time 2441[s] | perplexity 295.37
# | epoch 1 |  iter 701 / 1327 | time 2481[s] | perplexity 264.29
# | epoch 1 |  iter 801 / 1327 | time 2521[s] | perplexity 233.04
# | epoch 1 |  iter 901 / 1327 | time 2560[s] | perplexity 224.62
# | epoch 1 |  iter 1001 / 1327 | time 2598[s] | perplexity 223.98
# | epoch 1 |  iter 1101 / 1327 | time 2637[s] | perplexity 197.48
# | epoch 1 |  iter 1201 / 1327 | time 2677[s] | perplexity 195.81
# | epoch 1 |  iter 1301 / 1327 | time 2715[s] | perplexity 181.68
# | epoch 2 |  iter 1 / 1327 | time 2725[s] | perplexity 212.62
# | epoch 2 |  iter 101 / 1327 | time 2765[s] | perplexity 174.13
# | epoch 2 |  iter 201 / 1327 | time 2802[s] | perplexity 182.33
# | epoch 2 |  iter 301 / 1327 | time 2841[s] | perplexity 178.89
# | epoch 2 |  iter 401 / 1327 | time 2880[s] | perplexity 163.97
# | epoch 2 |  iter 501 / 1327 | time 2921[s] | perplexity 160.24
# | epoch 2 |  iter 601 / 1327 | time 2960[s] | perplexity 165.19
# | epoch 2 |  iter 701 / 1327 | time 3000[s] | perplexity 155.29
# | epoch 2 |  iter 801 / 1327 | time 3039[s] | perplexity 141.23
# | epoch 2 |  iter 901 / 1327 | time 3078[s] | perplexity 145.62
# | epoch 2 |  iter 1001 / 1327 | time 3116[s] | perplexity 149.90
# | epoch 2 |  iter 1101 / 1327 | time 3156[s] | perplexity 131.75
# | epoch 2 |  iter 1201 / 1327 | time 3195[s] | perplexity 134.98
# | epoch 2 |  iter 1301 / 1327 | time 3236[s] | perplexity 127.00
# | epoch 3 |  iter 1 / 1327 | time 3247[s] | perplexity 155.18
# | epoch 3 |  iter 101 / 1327 | time 3285[s] | perplexity 125.29
# | epoch 3 |  iter 201 / 1327 | time 3323[s] | perplexity 134.88
# | epoch 3 |  iter 301 / 1327 | time 3361[s] | perplexity 135.84
# | epoch 3 |  iter 401 / 1327 | time 3683[s] | perplexity 123.60
# | epoch 3 |  iter 501 / 1327 | time 3976[s] | perplexity 121.43
# | epoch 3 |  iter 601 / 1327 | time 4259[s] | perplexity 128.70
# | epoch 3 |  iter 701 / 1327 | time 4324[s] | perplexity 121.94
# | epoch 3 |  iter 801 / 1327 | time 4365[s] | perplexity 111.74
# | epoch 3 |  iter 901 / 1327 | time 4403[s] | perplexity 118.29
# | epoch 3 |  iter 1001 / 1327 | time 4442[s] | perplexity 122.20
# | epoch 3 |  iter 1101 / 1327 | time 4482[s] | perplexity 106.39
# | epoch 3 |  iter 1201 / 1327 | time 4521[s] | perplexity 109.63
# | epoch 3 |  iter 1301 / 1327 | time 4558[s] | perplexity 104.48
# | epoch 4 |  iter 1 / 1327 | time 4568[s] | perplexity 128.22
# | epoch 4 |  iter 101 / 1327 | time 4607[s] | perplexity 103.29
# | epoch 4 |  iter 201 / 1327 | time 4647[s] | perplexity 112.51
# | epoch 4 |  iter 301 / 1327 | time 4688[s] | perplexity 114.51
# | epoch 4 |  iter 401 / 1327 | time 4727[s] | perplexity 103.55
# | epoch 4 |  iter 501 / 1327 | time 4765[s] | perplexity 102.43
# | epoch 4 |  iter 601 / 1327 | time 4805[s] | perplexity 109.37
# | epoch 4 |  iter 701 / 1327 | time 4844[s] | perplexity 104.35
# | epoch 4 |  iter 801 / 1327 | time 4884[s] | perplexity 95.66
# | epoch 4 |  iter 901 / 1327 | time 4923[s] | perplexity 103.15
# | epoch 4 |  iter 1001 / 1327 | time 4962[s] | perplexity 107.24
# | epoch 4 |  iter 1101 / 1327 | time 5000[s] | perplexity 92.11
# | epoch 4 |  iter 1201 / 1327 | time 5040[s] | perplexity 95.27
# | epoch 4 |  iter 1301 / 1327 | time 5080[s] | perplexity 91.35
# evaluating perplexity ...
# 234 / 235
# test perplexity:  134.89292648377193

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.time_layers import *
import numpy as np
from common.base_model import BaseModel


class BetterRnnlm(BaseModel):
    '''
     LSTMレイヤを2層利用し、各層にDropoutを使うモデル
     [1]で提案されたモデルをベースとし、weight tying[2][3]を利用

     [1] Recurrent Neural Network Regularization (https://arxiv.org/abs/1409.2329)
     [2] Using the Output Embedding to Improve Language Models (https://arxiv.org/abs/1608.05859)
     [3] Tying Word Vectors and Word Classifiers (https://arxiv.org/pdf/1611.01462.pdf)
    '''
    def __init__(self, vocab_size=10000, wordvec_size=650,
                 hidden_size=650, dropout_ratio=0.5):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx1 = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh1 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b1 = np.zeros(4 * H).astype('f')
        lstm_Wx2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_Wh2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b2 = np.zeros(4 * H).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.layers = [
            TimeEmbedding(embed_W),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx1, lstm_Wh1, lstm_b1, stateful=True),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx2, lstm_Wh2, lstm_b2, stateful=True),
            TimeDropout(dropout_ratio),
            TimeAffine(embed_W.T, affine_b)  # weight tying!!
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layers = [self.layers[2], self.layers[4]]
        self.drop_layers = [self.layers[1], self.layers[3], self.layers[5]]

        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs, train_flg=False):
        for layer in self.drop_layers:
            layer.train_flg = train_flg

        for layer in self.layers:
            xs = layer.forward(xs)
        return xs

    def forward(self, xs, ts, train_flg=True):
        score = self.predict(xs, train_flg)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        for layer in self.lstm_layers:
            layer.reset_state()

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common import config
# GPUで実行する場合は下記のコメントアウトを消去（要cupy）
# ==============================================
config.GPU = True
# ==============================================
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity, to_gpu
from dataset import ptb

# ハイパーパラメータの設定
batch_size = 20
wordvec_size = 650
hidden_size = 650
time_size = 35
lr = 20.0
max_epoch = 40
max_grad = 0.25
dropout = 0.5

# 学習データの読み込み
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_val, _, _ = ptb.load_data('val')
corpus_test, _, _ = ptb.load_data('test')

if config.GPU:
    corpus = to_gpu(corpus)
    corpus_val = to_gpu(corpus_val)
    corpus_test = to_gpu(corpus_test)

vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

model = BetterRnnlm(vocab_size, wordvec_size, hidden_size, dropout)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

best_ppl = float('inf')
for epoch in range(max_epoch):
    trainer.fit(xs, ts, max_epoch=1, batch_size=batch_size,
                time_size=time_size, max_grad=max_grad)

    model.reset_state()
    ppl = eval_perplexity(model, corpus_val)
    print('valid perplexity: ', ppl)

    if best_ppl > ppl:
        best_ppl = ppl
        model.save_params()
    else:
        lr /= 4.0
        optimizer.lr = lr

    model.reset_state()
    print('-' * 50)


# テストデータでの評価
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('test perplexity: ', ppl_test)
# Out:
# | epoch 1 |  iter 1 / 1327 | time 26[s] | perplexity 9999.80
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 44
#      42 best_ppl = float('inf')
#      43 for epoch in range(max_epoch):
# ---> 44     trainer.fit(xs, ts, max_epoch=1, batch_size=batch_size,
#      45                 time_size=time_size, max_grad=max_grad)
#      47     model.reset_state()
#      48     ppl = eval_perplexity(model, corpus_val)
#
# File ~/dev/self-study/02_zero_dl_2_nlp/common/trainer.py:111, in RnnlmTrainer.fit(self, xs, ts, max_epoch, batch_size, time_size, max_grad, eval_interval)
#     109 # 勾配を求め、パラメータを更新
#     110 loss = model.forward(batch_x, batch_t)
# --> 111 model.backward()
#     112 params, grads = remove_duplicate(model.params, model.grads)  # 共有された重みを1つに集約
#     113 if max_grad is not None:
#
# Cell In[3], line 66, in BetterRnnlm.backward(self, dout)
#      64 dout = self.loss_layer.backward(dout)
#      65 for layer in reversed(self.layers):
# ---> 66     dout = layer.backward(dout)
#      67 return dout
#
# File ~/dev/self-study/02_zero_dl_2_nlp/common/time_layers.py:211, in TimeLSTM.backward(self, dhs)
#     209 for t in reversed(range(T)):
#     210     layer = self.layers[t]
# --> 211     dx, dh, dc = layer.backward(dhs[:, t, :] + dh, dc)
#     212     dxs[:, t, :] = dx
#     213     for i, grad in enumerate(layer.grads):
#
# File ~/dev/self-study/02_zero_dl_2_nlp/common/time_layers.py:162, in LSTM.backward(self, dh_next, dc_next)
#     159 self.grads[1][...] = dWh
#     160 self.grads[2][...] = db
# --> 162 dx = np.dot(dA, Wx.T)
#     163 dh_prev = np.dot(dA, Wh.T)
#     165 return dx, dh_prev, dc_prev
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
